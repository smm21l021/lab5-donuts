# %%
# !wget https://github.com/smm21l021/lab5-donuts-dataset/blob/main/donuts-dataset.zip
# !unzip donuts-dataset.zip
# Out:
# --2026-03-22 19:13:07--  https://github.com/smm21l021/lab5-donuts-dataset/blob/main/donuts-dataset.zip
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘donuts-dataset.zip.1’
#
# donuts-dataset.zip.     [ <=>                ] 217.20K  --.-KB/s    in 0.03s
#
# 2026-03-22 19:13:07 (7.47 MB/s) - ‘donuts-dataset.zip.1’ saved [222417]
#
# Archive:  donuts-dataset.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of donuts-dataset.zip or
#         donuts-dataset.zip.zip, and cannot find donuts-dataset.zip.ZIP, period.
